# %%
from lerobot.datasets.lerobot_dataset import LeRobotDataset
from lerobot.datasets.dataset_tools import merge_datasets

ds_a = LeRobotDataset("dinura/so101_pickup_lego_v2",
                      root="/Users/dinura.dissanayake/lerobot_data/so101_pickup_lego_v2")
ds_b = LeRobotDataset("dinura/so101_pickup_lego_v3",
                      root="/Users/dinura.dissanayake/lerobot_data/so101_pickup_lego_v3")

merge_datasets([ds_a, ds_b], output_repo_id="/Users/dinura.dissanayake/lerobot_data/so101_pickup_lego_merged")
# Out:
# ...
# Copy data and videos: 100%|██████████| 2/2 [00:07<00:00,  3.79s/it]
# LeRobotDataset({
#     Repository ID: '/Users/dinura.dissanayake/lerobot_data/so101_pickup_lego_merged',
#     Number of selected episodes: '200',
#     Number of selected samples: '165515',
#     Features: '['action', 'observation.state', 'observation.images.front', 'observation.images.wrist', 'timestamp', 'frame_index', 'episode_index', 'index', 'task_index']',
# })
